# %% [markdown]
# ## Model Data

# %%
# Import Libraries
import numpy             as np 
import pandas            as pd 
import matplotlib.pyplot as plt
import seaborn           as sns

# %%
# Load data
data = pd.read_csv('../../cross_sell_clean2.csv')

# %%
# cap outliers
data.loc[data['days_to_activation'] > 150, 'days_to_activation'] = 150

data['weeks_to_activation'] = data['days_to_activation']/7

# %% [markdown]
# ## Feature Selection

# %%
columns = [  'xseller',
             'orderyear',
             'ordermonth',     
             'regtenure',
             'customer_type_group',
             'weeks_to_activation',
             'weekstogetresult_grp',
             'traffic_source',
             'kits_ordered',
             'kit_activation_rate',
             'kit_completion_rate'
]

model_data = data[columns]

# %%
# Plot Correlation Matrix

# Generate and visualize the correlation matrix
corr = model_data.corr().round(2)

# Mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
f, ax = plt.subplots(figsize=(20, 20))

# Define custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=False)

plt.tight_layout()

# %%
# Prepare data for modeling

# weekstogetresult_grp : convert to numeric
model_data['weekstogetresult_grp'] = model_data['weekstogetresult_grp'].replace('>10s', '12')
model_data['weekstogetresult_grp'] = pd.to_numeric(model_data['weekstogetresult_grp'])

# regtenure : convert to numeric
model_data['regtenure'] = model_data['regtenure'].str.replace('<=', '')
model_data['regtenure'].replace('>120', '150',  inplace=True)
model_data['regtenure'] = pd.to_numeric(model_data['regtenure'])

# customer_type_group to binary
# Existing Reg = 1, New Reg = 0
model_data['customer_type_group'] = (model_data['customer_type_group'] == 'Existing Reg').astype('int')

# year, month, and traffic_source dummy variables
model_data = pd.get_dummies(model_data, columns=['orderyear', 'ordermonth', 'traffic_source'], drop_first=True)
# Out:
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/georgebofysil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Handle Null Values
model_data.isnull().sum(axis=0)
# Out:
# xseller                                   0
# regtenure                               223
# customer_type_group                       0
# weeks_to_activation                   48039
# weekstogetresult_grp                  67168
# kits_ordered                              0
# kit_activation_rate                       0
# kit_completion_rate                       0
# orderyear_2012.0                          0
# orderyear_2013.0                          0
# orderyear_2014.0                          0
# orderyear_2015.0                          0
# orderyear_2016.0                          0
# orderyear_2017.0                          0
# ordermonth_2.0                            0
# ordermonth_3.0                            0
# ordermonth_4.0                            0
# ordermonth_5.0                            0
# ordermonth_6.0                            0
# ordermonth_7.0                            0
# ordermonth_8.0                            0
# ordermonth_9.0                            0
# ordermonth_10.0                           0
# ordermonth_11.0                           0
# ordermonth_12.0                           0
# traffic_source_app                        0
# traffic_source_content marketing          0
# traffic_source_direct                     0
# traffic_source_email                      0
# traffic_source_external paid media        0
# traffic_source_external referrals         0
# traffic_source_internal referrals         0
# traffic_source_organic search             0
# traffic_source_other                      0
# traffic_source_paid search                0
# traffic_source_social                     0
# traffic_source_unknown                    0
# dtype: int64

# %% [markdown]
# ## Run Model

# %%
# Create training data
X = model_data.drop('xseller', axis=1)
y = model_data['xseller']

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %%
## Model Pipeline
from sklearn.pipeline      import Pipeline, make_pipeline
from sklearn.preprocessing import Imputer, StandardScaler
from sklearn.linear_model  import LogisticRegression
from sklearn.ensemble      import RandomForestClassifier

# L1 Logistic
log_pipeline = Pipeline(memory=None,
                        steps = [('imputer'   , Imputer(missing_values='NaN', strategy='mean', axis=0)),
                                 #('scaler'    , StandardScaler()),
                                 ('classifier', LogisticRegression(class_weight='balanced', penalty="l2", C=.01, tol=.00000001))]
                       )

logcv_pipeline = Pipeline(memory=None,
                          steps = [('imputer'   , Imputer(missing_values='NaN', strategy='mean', axis=0)),
                                   ('classifier', LogisticRegression(class_weight={0:.1,1:.8}, penalty="l1"))]
                       )
# Random Forest
rf_pipeline  = make_pipeline(Imputer(missing_values='NaN', strategy='mean', axis=0),
                             StandardScaler(),
                             RandomForestClassifier())

# %%
# Impute missing values
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
X_statsmodel = imp.fit_transform(X)

# %%
# Statsmodel
import statsmodels.api as sm
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

logit = sm.Logit(y, X_statsmodel)

# fit the model
result = logit.fit()

result.summary()
np.exp(result.params)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449464
#          Iterations 7
# x1     1.003098
# x2     0.907239
# x3     0.972807
# x4     0.989947
# x5     0.939604
# x6     2.973344
# x7     1.307369
# x8     1.017000
# x9     0.142946
# x10    0.121410
# x11    0.117109
# x12    0.110555
# x13    0.067604
# x14    0.940586
# x15    0.741138
# x16    0.761343
# x17    0.794952
# x18    0.768087
# x19    0.846729
# x20    0.798611
# x21    0.781816
# x22    0.754271
# x23    0.791976
# x24    0.722460
# x25    1.777574
# x26    1.297011
# x27    1.101288
# x28    1.002142
# x29    1.123158
# x30    1.071537
# x31    1.035823
# x32    1.035630
# x33    0.954387
# x34    0.986723
# x35    1.533674
# x36    0.873064
# dtype: float64

# %%
# Run Logistic Pipeline - large_core_data
from sklearn.metrics import classification_report, confusion_matrix, make_scorer
from visualizations import plot_roc

log_pipeline.fit(X_train, y_train)
log_predictions = log_pipeline.predict(X_test)

# Print Precision & Recall
print(classification_report(y_test, log_predictions))

# Print ROC Curve
plot_roc(y_test, log_pipeline.predict_proba(X_test))

# Print Feature Coefficients
classifier = log_pipeline.named_steps['classifier']
coef = classifier.coef_[0]
odds = np.exp(coef)

feature_names = X.columns.values.tolist()
feature_odds_data = pd.DataFrame({'feature': feature_names, 'odds_ratio': odds})
feature_odds_data
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.50      0.65     37256
#           1       0.26      0.78      0.39      8588
#
# avg / total       0.79      0.55      0.60     45844
#
# ROC AUC: 0.68
#                                feature  odds_ratio
# 0                            regtenure    1.003061
# 1                  customer_type_group    0.918296
# 2                  weeks_to_activation    0.974578
# 3                 weekstogetresult_grp    0.991216
# 4                         kits_ordered    0.940927
# 5                  kit_activation_rate    2.765332
# 6                  kit_completion_rate    1.371223
# 7                     orderyear_2012.0    2.639179
# 8                     orderyear_2013.0    0.943333
# 9                     orderyear_2014.0    0.813436
# 10                    orderyear_2015.0    0.788979
# 11                    orderyear_2016.0    0.753722
# 12                    orderyear_2017.0    0.524954
# 13                      ordermonth_2.0    1.001355
# 14                      ordermonth_3.0    0.777844
# 15                      ordermonth_4.0    0.834447
# 16                      ordermonth_5.0    0.883742
# 17                      ordermonth_6.0    0.869410
# 18                      ordermonth_7.0    0.972993
# 19                      ordermonth_8.0    0.884401
# 20                      ordermonth_9.0    0.899549
# 21                     ordermonth_10.0    0.861896
# 22                     ordermonth_11.0    0.856219
# 23                     ordermonth_12.0    0.768463
# 24                  traffic_source_app    1.328387
# 25    traffic_source_content marketing    1.164558
# 26               traffic_source_direct    1.049702
# 27                traffic_source_email    0.937094
# 28  traffic_source_external paid media    1.064384
# 29   traffic_source_external referrals    0.971099
# 30   traffic_source_internal referrals    0.976405
# 31       traffic_source_organic search    0.968605
# 32                traffic_source_other    0.918654
# 33          traffic_source_paid search    0.934794
# 34               traffic_source_social    1.108285
# 35              traffic_source_unknown    0.840318

# %%
# Run RandomForest Pipeline
rf_pipeline.fit(X_train, y_train)
rf_predictions = rf_pipeline.predict(X_test)
print(classification_report(y_test, rf_predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.92      0.87     37256
#           1       0.28      0.14      0.19      8588
#
# avg / total       0.72      0.77      0.74     45844
